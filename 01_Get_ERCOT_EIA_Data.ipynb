# %% [markdown]
# This notebook:
# 1. Gets plant metadata from ERCOT and EIA
# 2. Tries to match up that metadata to positively ID plants
# 3. For plants with a metadata match, it pulls timeseries data from ERCOT using the gridstatus.io API
# 4. Writes specs (metadata) and timeseries power data for each plant into .csv files to be processed later.
#
# _Code for pulling from gridstatus.io and matching with EIA was based on code by Drumil Joshi, Southern Power Company._

# %%
## API key credentials are stored in a separate text file
with open('gridstatus_api_key.txt') as f: # full path and filename of text file with api key on first line
    api_key = f.readline().rstrip()  # rstrip removes trailing line breaks and spaces

# %%
import pandas as pd
import os
# from fuzzywuzzy import process
from thefuzz import process # thefuzz seems better and faster than fuzzywuzzy
from gridstatusio import GridStatusClient
import urllib.request 
import zipfile
import re
import time

# %% [markdown]
# Get ERCOT Capacity Demand Reserves (CDR) report file for mapping ERCOT unit names with EIA plant names:

# %%
ercot_cdr_url = 'https://www.ercot.com/files/docs/2024/05/24/CapacityDemandandReservesReport_May2024_Revised.xlsx'
cdr_filename = 'input_specs/CapacityDemandandReservesReport_May2024_Revised.xlsx'
urllib.request.urlretrieve(ercot_cdr_url, cdr_filename)
# Out:
# ('input_specs/CapacityDemandandReservesReport_May2024_Revised.xlsx',
#  <http.client.HTTPMessage at 0x2aeefaf03e0>)

# %% [markdown]
# Create a dataframe of just the solar plants:

# %%
CDR_FILE = cdr_filename
CDR_SHEET = "SummerCapacities"
cdr_df = pd.read_excel(CDR_FILE, sheet_name=CDR_SHEET, header=1)
cdr_df = cdr_df[cdr_df['FUEL'] == 'SOLAR']
cdr_df.head()
# Out:
#      Unnamed: 0           UNIT NAME  INR         UNIT CODE    COUNTY   FUEL  \
# 876       879.0        ACACIA SOLAR  NaN     ACACIA_UNIT_1  PRESIDIO  SOLAR
# 877       880.0        ALEXIS SOLAR  NaN  DG_ALEXIS_ALEXIS    BROOKS  SOLAR
# 878       881.0  ANDROMEDA SOLAR U1  NaN    ANDMDSLR_UNIT1    SCURRY  SOLAR
# 879       882.0  ANDROMEDA SOLAR U2  NaN    ANDMDSLR_UNIT2    SCURRY  SOLAR
# 880       883.0      ANSON SOLAR U1  NaN      ANSON1_UNIT1     JONES  SOLAR
#
#       ZONE  IN SERVICE  INSTALLED CAPACITY \nRATING \n(MW)   2025   2026  \
# 876   WEST      2012.0                                10.0   10.0   10.0
# 877  SOUTH      2019.0                                10.0   10.0   10.0
# 878   WEST      2024.0                               158.8  158.0  158.0
# 879   WEST      2024.0                               162.4  162.0  162.0
# 880   WEST      2022.0                               100.8  100.0  100.0
#
#       2027   2028   2029   2030   2031   2032   2033   2034
# 876   10.0   10.0   10.0   10.0   10.0   10.0   10.0   10.0
# 877   10.0   10.0   10.0   10.0   10.0   10.0   10.0   10.0
# 878  158.0  158.0  158.0  158.0  158.0  158.0  158.0  158.0
# 879  162.0  162.0  162.0  162.0  162.0  162.0  162.0  162.0
# 880  100.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0

# %% [markdown]
# Get EIA plant data. It's in a zip file:

# %%
eia_860_url = 'https://www.eia.gov/electricity/data/eia860/xls/eia8602023.zip'
filehandle, _ = urllib.request.urlretrieve(eia_860_url)
zip_file_object = zipfile.ZipFile(filehandle, 'r')

# %% [markdown]
# Look at filenames in the zip file. We want `2__Plant*.xlsx` and `3_3_Solar*.xlsx`:

# %%
zip_file_object.namelist()
# Out:
# ['1___Utility_Y2023.xlsx',
#  '2___Plant_Y2023.xlsx',
#  '3_1_Generator_Y2023.xlsx',
#  '3_2_Wind_Y2023.xlsx',
#  '3_3_Solar_Y2023.xlsx',
#  '3_4_Energy_Storage_Y2023.xlsx',
#  '3_5_Multifuel_Y2023.xlsx',
#  '4___Owner_Y2023.xlsx',
#  '6_1_EnviroAssoc_Y2023.xlsx',
#  '6_2_EnviroEquip_Y2023.xlsx',
#  'EIA-860 Form.xlsx',
#  'EIA-860 instructions.pdf',
#  'LayoutY2023.xlsx']

# %%
EIA_PLANT_FILE = zip_file_object.extract(
    zip_file_object.namelist()[1], # second file in the list above
    path='input_specs/') 
EIA_SOLAR_FILE = zip_file_object.extract(
    zip_file_object.namelist()[4], # 5th file in the list above
    path='input_specs/')

# %%
eia_plant_df = pd.read_excel(EIA_PLANT_FILE, sheet_name="Plant", header=1)
eia_solar_df = pd.read_excel(EIA_SOLAR_FILE, sheet_name="Operable", header=1)

# %% [markdown]
# Merge EIA dataframes on Plant Code to add latitude and longitude to the Solar data:

# %%
eia_df = eia_solar_df.merge(eia_plant_df[['Plant Code', 'Latitude', 'Longitude']], on='Plant Code', how='inner')
eia_df.head()
# Out:
#    Utility ID                          Utility Name  Plant Code  \
# 0       16572                    Salt River Project         141
# 1       18454                     Tampa Electric Co         645
# 2        7095                City of Geneseo - (IL)         944
# 3       16179          Rochelle Municipal Utilities         960
# 4        6235  Fayetteville Public Works Commission        1016
#
#                        Plant Name State        County Generator ID Status  \
# 0                       Agua Fria    AZ      Maricopa         PV-3     OP
# 1                        Big Bend    FL  Hillsborough            1     OP
# 2                         Geneseo    IL         Henry           12     OP
# 3              North Ninth Street    IL          Ogle         SOL1     OP
# 4  Butler-Warner Generation Plant    NC    Cumberland           10     OP
#
#            Technology Prime Mover  ... Thin-Film (A-Si)?  Thin-Film (CIGS)?  \
# 0  Solar Photovoltaic          PV  ...               NaN                NaN
# 1  Solar Photovoltaic          PV  ...               NaN                NaN
# 2  Solar Photovoltaic          PV  ...               NaN                NaN
# 3  Solar Photovoltaic          PV  ...               NaN                NaN
# 4  Solar Photovoltaic          PV  ...               NaN                NaN
#
#    Thin-Film (Other)?  Other Materials?  Net Metering Agreement?  \
# 0                 NaN               NaN                        N
# 1                 NaN               NaN                        N
# 2                 NaN               NaN                        N
# 3                 NaN               NaN                        Y
# 4                 NaN               NaN                        N
#
#    Net Metering DC Capacity (MW)  Virtual Net Metering Agreement?  \
# 0                                                               N
# 1                                                               N
# 2                                                               N
# 3                            0.3                                N
# 4                                                               N
#
#   Virtual Net Metering DC Capacity (MW)   Latitude  Longitude
# 0                                          33.5561  -112.2153
# 1                                          27.7944   -82.4036
# 2                                        41.451494 -90.148547
# 3                                          41.9093   -89.0498
# 4                                          35.0986   -78.8294
#
# [5 rows x 43 columns]

# %% [markdown]
# Filter EIA to only Texas

# %%
eia_df = eia_df[eia_df['State'] == 'TX'].copy()

# %% [markdown]
# Make a column in EIA df that is plant name and county:

# %%
eia_df['plant_name_county'] = eia_df[['Plant Name','County']].agg(' '.join,axis=1)

# %% [markdown]
# Function to merge CDR and EIA data. It combines plant names and counties into a single string. It also removes anything in parentheses in the CDR plant name (this seemed to cause problems, but maybe not always...).

# %%
def merge_cdr_with_eia_info(selected_unit_names, cdr_df, eia_df):
    choices = eia_df['plant_name_county'].unique()
    cdr_column_nameplate = "INSTALLED CAPACITY \nRATING \n(MW)"
    eia_solar_columns = eia_df.columns.tolist()
    output_data = []
    i=0
    for unit_name in selected_unit_names:
        cdr_row = cdr_df[cdr_df["UNIT NAME"] == unit_name]
        if cdr_row.empty:
            print(f"CDR unit '{unit_name}' not found.")
            continue
        cdr_row = cdr_row.iloc[0]
        unit_county = cdr_df[cdr_df["UNIT NAME"] == unit_name].iloc[0]['COUNTY']
        cdr_unit_name_county = unit_name + ' ' + unit_county

        # remove anything in parentheses or brackets
        cdr_unit_name_county = re.sub("[\(\[].*?[\)\]]", "", cdr_unit_name_county)
        # remove multiple spaces
        cdr_unit_name_county = re.sub(' +', ' ', cdr_unit_name_county)

        # eia_match_name, score = process.extractOne(unit_name_test, choices)
        eia_match_name_county, score = process.extractOne(cdr_unit_name_county, choices)
        if score < 87:
            print(f"No strong EIA match for '{cdr_unit_name_county}' (Best guess: {eia_match_name_county}, Score: {score})")
            eia_match_row = None
        else:
            eia_match_row = eia_df[eia_df['plant_name_county'] == eia_match_name_county].iloc[0]

        output_data.append({
            "cdr file unit name": unit_name,
            "cdr unit code": cdr_row['UNIT CODE'],
            "cdr file nameplate ac mw": cdr_row[cdr_column_nameplate],
            "cdr file county": cdr_row['COUNTY'],
            "eia plant name": eia_match_row["Plant Name"] if score >= 87 else None,
            "eia county": eia_match_row["County"] if score >= 87 else None,
            "eia nameplate ac": eia_match_row["Nameplate Capacity (MW)"] if eia_match_row is not None else None,
            "eia lat": eia_match_row["Latitude"] if eia_match_row is not None else None,
            "eia lon": eia_match_row["Longitude"] if eia_match_row is not None else None,
        })

        # Add full EIA columns
        if eia_match_row is not None:
            for col in eia_solar_columns:
                output_data[i][f"eia solar {col}"] = eia_match_row.loc[col]
        else:
            print(f"⚠ No EIA Solar row matching CDR: {cdr_unit_name_county}")
        i += 1


    return pd.DataFrame(output_data)
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\('
# <>:17: SyntaxWarning: invalid escape sequence '\('
# C:\Users\willh\AppData\Local\Temp\ipykernel_49516\2495095591.py:17: SyntaxWarning: invalid escape sequence '\('
#   cdr_unit_name_county = re.sub("[\(\[].*?[\)\]]", "", cdr_unit_name_county)

# %% [markdown]
# Then run it on lists of plant names taken from the CDR file. Plants were filtered to be in service 2022 or sooner and greater than 30 MW, then the first ~10 plants from each region (alphabetical) with unique names were selected.

# %%
# west
unit_list = [
'ANSON SOLAR U1',
'ARAGORN SOLAR',
'AZURE SKY SOLAR U1',
'BHE SOLAR PEARL PROJECT (SIRIUS 2)',
'BLUEBELL SOLAR II 1 (CAPRICORN RIDGE 4)',
# 'BNB LAMESA SOLAR (PHASE I)', # skip this one
'CASTLE GAP SOLAR',
'EUNICE SOLAR U1',
'FOWLER RANCH',
# 'FS EAST PECOS SOLAR', # skip this one too
'GALLOWAY 1 SOLAR',
'GREASEWOOD SOLAR 1',
'HOLSTEIN SOLAR 1',
'JUNO SOLAR PHASE I',
'LAPETUS SOLAR',
]

merged_df_west = merge_cdr_with_eia_info(unit_list, cdr_df, eia_df)
merged_df_west
# Out:
# No strong EIA match for 'BHE SOLAR PEARL PROJECT PECOS' (Best guess: Barilla Solar Pecos, Score: 86)
# ⚠ No EIA Solar row matching CDR: BHE SOLAR PEARL PROJECT PECOS
# No strong EIA match for 'EUNICE SOLAR U1 ANDREWS' (Best guess: Blue Wing Solar Energy Generation Bexar, Score: 86)
# ⚠ No EIA Solar row matching CDR: EUNICE SOLAR U1 ANDREWS
# No strong EIA match for 'FOWLER RANCH CRANE' (Best guess: CED Crane Solar Crane, Score: 56)
# ⚠ No EIA Solar row matching CDR: FOWLER RANCH CRANE
# No strong EIA match for 'JUNO SOLAR PHASE I BORDEN' (Best guess: Blue Wing Solar Energy Generation Bexar, Score: 86)
# ⚠ No EIA Solar row matching CDR: JUNO SOLAR PHASE I BORDEN
#                          cdr file unit name     cdr unit code  \
# 0                            ANSON SOLAR U1      ANSON1_UNIT1
# 1                             ARAGORN SOLAR     ARAGORN_UNIT1
# 2                        AZURE SKY SOLAR U1      AZURE_SOLAR1
# 3        BHE SOLAR PEARL PROJECT (SIRIUS 2)      SIRIUS_UNIT2
# 4   BLUEBELL SOLAR II 1 (CAPRICORN RIDGE 4)  CAPRIDG4_BB2_PV1
# 5                          CASTLE GAP SOLAR    CASL_GAP_UNIT1
# 6                           EUNICE SOLAR U1        EUNICE_PV1
# 7                              FOWLER RANCH    FWLR_SLR_UNIT1
# 8                          GALLOWAY 1 SOLAR   GALLOWAY_SOLAR1
# 9                        GREASEWOOD SOLAR 1    GREASWOD_UNIT1
# 10                         HOLSTEIN SOLAR 1   HOLSTEIN_SOLAR1
# 11                       JUNO SOLAR PHASE I        JUNO_UNIT1
# 12                            LAPETUS SOLAR    LAPETUS_UNIT_1
#
#     cdr file nameplate ac mw cdr file county           eia plant name  \
# 0                      100.8           JONES  ANSON Solar Center, LLC
# 1                      188.2       CULBERSON    Aragorn Solar Project
# 2                       74.9         HASKELL          Azure Sky Solar
# 3                       50.0           PECOS                     None
# 4                      100.0        STERLING        Bluebell Solar II
# 5                      180.0           UPTON  Castle Gap Solar Hybrid
# 6                      189.6         ANDREWS                     None
# 7                      152.5           CRANE                     None
# 8                      250.0          CONCHO    Galloway 1 Solar Farm
# 9                      126.3           PECOS         Greasewood Solar
# 10                     102.2           NOLAN    Holstein 1 Solar Farm
# 11                     162.1          BORDEN                     None
# 12                     100.7         ANDREWS                  Lapetus
#
#    eia county  eia nameplate ac    eia lat     eia lon  eia solar Utility ID  \
# 0       Jones             200.0  32.811041  -99.917490               56201.0
# 1   Culberson             187.2  31.719983 -104.442292               63101.0
# 2     Haskell             225.0  33.021601  -99.614630               63571.0
# 3        None               NaN        NaN         NaN                   NaN
# 4    Sterling             115.0  31.888000 -100.825000               63116.0
# 5       Upton             180.0  31.255000 -102.272000               61123.0
# 6        None               NaN        NaN         NaN                   NaN
# 7        None               NaN        NaN         NaN                   NaN
# 8      Concho             250.0  31.435932  -99.796613               61523.0
# 9       Pecos             255.0  31.030996 -102.488209               62705.0
# 10      Nolan             200.0  32.104125 -100.162375               65411.0
# 11       None               NaN        NaN         NaN                   NaN
# 12    Andrews             100.0  32.460054 -102.672809               65411.0
#
#     ... eia solar Thin-Film (CIGS)?  eia solar Thin-Film (Other)?  \
# 0   ...                         NaN                           NaN
# 1   ...                         NaN                           NaN
# 2   ...                         NaN                           NaN
# 3   ...                         NaN                           NaN
# 4   ...                         NaN                           NaN
# 5   ...                         NaN                           NaN
# 6   ...                         NaN                           NaN
# 7   ...                         NaN                           NaN
# 8   ...                         NaN                           NaN
# 9   ...                         NaN                           NaN
# 10  ...                         NaN                           NaN
# 11  ...                         NaN                           NaN
# 12  ...                         NaN                           NaN
#
#    eia solar Other Materials? eia solar Net Metering Agreement?  \
# 0                         NaN                                 N
# 1                         NaN                                 N
# 2                         NaN                                 N
# 3                         NaN                               NaN
# 4                         NaN                                 N
# 5                         NaN                                 N
# 6                         NaN                               NaN
# 7                         NaN                               NaN
# 8                         NaN                                 N
# 9                         NaN                                 N
# 10                        NaN                                 N
# 11                        NaN                               NaN
# 12                        NaN                                 N
#
#    eia solar Net Metering DC Capacity (MW)  \
# 0
# 1
# 2
# 3                                      NaN
# 4
# 5
# 6                                      NaN
# 7                                      NaN
# 8
# 9
# 10
# 11                                     NaN
# 12
#
#    eia solar Virtual Net Metering Agreement?  \
# 0                                          N
# 1                                          N
# 2                                          N
# 3                                        NaN
# 4                                          N
# 5                                          N
# 6                                        NaN
# 7                                        NaN
# 8                                          N
# 9                                          N
# 10                                         N
# 11                                       NaN
# 12                                         N
#
#    eia solar Virtual Net Metering DC Capacity (MW) eia solar Latitude  \
# 0                                                           32.811041
# 1                                                           31.719983
# 2                                                           33.021601
# 3                                              NaN                NaN
# 4                                                           31.888000
# 5                                                           31.255000
# 6                                              NaN                NaN
# 7                                              NaN                NaN
# 8                                                           31.435932
# 9                                                           31.030996
# 10                                                          32.104125
# 11                                             NaN                NaN
# 12                                                          32.460054
#
#    eia solar Longitude      eia solar plant_name_county
# 0           -99.917490    ANSON Solar Center, LLC Jones
# 1          -104.442292  Aragorn Solar Project Culberson
# 2           -99.614630          Azure Sky Solar Haskell
# 3                  NaN                              NaN
# 4          -100.825000       Bluebell Solar II Sterling
# 5          -102.272000    Castle Gap Solar Hybrid Upton
# 6                  NaN                              NaN
# 7                  NaN                              NaN
# 8           -99.796613     Galloway 1 Solar Farm Concho
# 9          -102.488209           Greasewood Solar Pecos
# 10         -100.162375      Holstein 1 Solar Farm Nolan
# 11                 NaN                              NaN
# 12         -102.672809                  Lapetus Andrews
#
# [13 rows x 53 columns]

# %%
# north
unit_list = [
    'CONIGLIO SOLAR',
'IMPACT SOLAR',
'KELLAM SOLAR',
'LILY SOLAR',
'NOBLE SOLAR U1',
'PHOENIX SOLAR',
'RIPPEY SOLAR',
'STRATEGIC SOLAR 1',
'VISION SOLAR 1',
'AGATE SOLAR',

]
merged_df_north = merge_cdr_with_eia_info(unit_list, cdr_df, eia_df)
merged_df_north
# Out:
# No strong EIA match for 'PHOENIX SOLAR FANNIN' (Best guess: Blue Wing Solar Energy Generation Bexar, Score: 86)
# ⚠ No EIA Solar row matching CDR: PHOENIX SOLAR FANNIN
# No strong EIA match for 'RIPPEY SOLAR COOKE' (Best guess: Blue Wing Solar Energy Generation Bexar, Score: 86)
# ⚠ No EIA Solar row matching CDR: RIPPEY SOLAR COOKE
# No strong EIA match for 'STRATEGIC SOLAR 1 ELLIS' (Best guess: Blue Wing Solar Energy Generation Bexar, Score: 86)
# ⚠ No EIA Solar row matching CDR: STRATEGIC SOLAR 1 ELLIS
# No strong EIA match for 'VISION SOLAR 1 NAVARRO' (Best guess: Blue Wing Solar Energy Generation Bexar, Score: 86)
# ⚠ No EIA Solar row matching CDR: VISION SOLAR 1 NAVARRO
# No strong EIA match for 'AGATE SOLAR ELLIS' (Best guess: Blue Wing Solar Energy Generation Bexar, Score: 86)
# ⚠ No EIA Solar row matching CDR: AGATE SOLAR ELLIS
#   cdr file unit name    cdr unit code  cdr file nameplate ac mw  \
# 0     CONIGLIO SOLAR   CONIGLIO_UNIT1                     125.7
# 1       IMPACT SOLAR     IMPACT_UNIT1                     198.5
# 2       KELLAM SOLAR   KELAM_SL_UNIT1                      59.8
# 3         LILY SOLAR      LILY_SOLAR1                     147.6
# 4     NOBLE SOLAR U1  NOBLESLR_SOLAR1                     148.8
# 5      PHOENIX SOLAR    PHOENIX_UNIT1                      83.9
# 6       RIPPEY SOLAR     RIPPEY_UNIT1                      59.8
# 7  STRATEGIC SOLAR 1   STRATEGC_UNIT1                     135.0
# 8     VISION SOLAR 1     VISION_UNIT1                     129.2
# 9        AGATE SOLAR              NaN                      60.0
#
#   cdr file county     eia plant name eia county  eia nameplate ac    eia lat  \
# 0          FANNIN     Coniglio Solar     Fannin             123.6  33.404486
# 1           LAMAR     Impact Solar 1      Lamar             198.5  33.467803
# 2       VAN ZANDT       Kellam Solar  Van Zandt              59.0  32.474400
# 3         KAUFMAN  Lily Solar Hybrid    Kaufman             146.7  32.533273
# 4          DENTON        Noble Solar     Denton             275.0  33.261505
# 5          FANNIN               None       None               NaN        NaN
# 6           COOKE               None       None               NaN        NaN
# 7           ELLIS               None       None               NaN        NaN
# 8         NAVARRO               None       None               NaN        NaN
# 9           ELLIS               None       None               NaN        NaN
#
#      eia lon  eia solar Utility ID  ... eia solar Thin-Film (CIGS)?  \
# 0 -96.082472               62680.0  ...                         NaN
# 1 -95.370856               62842.0  ...                         NaN
# 2 -95.715600               62682.0  ...                         NaN
# 3 -96.428985               63549.0  ...                         NaN
# 4 -97.238057               64568.0  ...                         NaN
# 5        NaN                   NaN  ...                         NaN
# 6        NaN                   NaN  ...                         NaN
# 7        NaN                   NaN  ...                         NaN
# 8        NaN                   NaN  ...                         NaN
# 9        NaN                   NaN  ...                         NaN
#
#    eia solar Thin-Film (Other)? eia solar Other Materials?  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# 5                           NaN                        NaN
# 6                           NaN                        NaN
# 7                           NaN                        NaN
# 8                           NaN                        NaN
# 9                           NaN                        NaN
#
#   eia solar Net Metering Agreement? eia solar Net Metering DC Capacity (MW)  \
# 0                                 N
# 1                                 N
# 2                                 N
# 3                                 N
# 4                                 N
# 5                               NaN                                     NaN
# 6                               NaN                                     NaN
# 7                               NaN                                     NaN
# 8                               NaN                                     NaN
# 9                               NaN                                     NaN
#
#   eia solar Virtual Net Metering Agreement?  \
# 0                                         N
# 1                                         N
# 2                                         N
# 3                                         N
# 4                                         N
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
#
#   eia solar Virtual Net Metering DC Capacity (MW) eia solar Latitude  \
# 0                                                          33.404486
# 1                                                          33.467803
# 2                                                          32.474400
# 3                                                          32.533273
# 4                                                          33.261505
# 5                                             NaN                NaN
# 6                                             NaN                NaN
# 7                                             NaN                NaN
# 8                                             NaN                NaN
# 9                                             NaN                NaN
#
#   eia solar Longitude eia solar plant_name_county
# 0          -96.082472       Coniglio Solar Fannin
# 1          -95.370856        Impact Solar 1 Lamar
# 2          -95.715600      Kellam Solar Van Zandt
# 3          -96.428985   Lily Solar Hybrid Kaufman
# 4          -97.238057          Noble Solar Denton
# 5                 NaN                         NaN
# 6                 NaN                         NaN
# 7                 NaN                         NaN
# 8                 NaN                         NaN
# 9                 NaN                         NaN
#
# [10 rows x 53 columns]

# %%
# south
unit_list = [
    'CORAZON SOLAR PHASE I',
'EAST BLACKLAND SOLAR (PFLUGERVILLE SOLAR)',
'ELARA SOLAR',
'OCI ALAMO 1 SOLAR',

]

merged_df_south = merge_cdr_with_eia_info(unit_list, cdr_df, eia_df)
merged_df_south
# Out:
# No strong EIA match for 'CORAZON SOLAR PHASE I WEBB' (Best guess: Blue Wing Solar Energy Generation Bexar, Score: 86)
# ⚠ No EIA Solar row matching CDR: CORAZON SOLAR PHASE I WEBB
#                           cdr file unit name   cdr unit code  \
# 0                      CORAZON SOLAR PHASE I   CORAZON_UNIT1
# 1  EAST BLACKLAND SOLAR (PFLUGERVILLE SOLAR)  E_BLACK_UNIT_1
# 2                                ELARA SOLAR  ELARA_SL_UNIT1
# 3                          OCI ALAMO 1 SOLAR  OCI_ALM1_UNIT1
#
#    cdr file nameplate ac mw cdr file county                  eia plant name  \
# 0                     202.6            WEBB                            None
# 1                     144.0          TRAVIS  East Blackland Solar Project 1
# 2                     132.4            FRIO                     Elara Solar
# 3                      39.2           BEXAR        OCI Alamo Solar I Hybrid
#
#   eia county  eia nameplate ac    eia lat    eia lon  eia solar Utility ID  \
# 0       None               NaN        NaN        NaN                   NaN
# 1     Travis             144.0  30.421400 -97.461400               65411.0
# 2       Frio             132.4  28.883196 -99.178605               62842.0
# 3      Bexar              40.7  29.271667 -98.444722               58489.0
#
#    ... eia solar Thin-Film (CIGS)?  eia solar Thin-Film (Other)?  \
# 0  ...                         NaN                           NaN
# 1  ...                         NaN                           NaN
# 2  ...                         NaN                           NaN
# 3  ...                         NaN                           NaN
#
#   eia solar Other Materials? eia solar Net Metering Agreement?  \
# 0                        NaN                               NaN
# 1                        NaN                                 N
# 2                        NaN                                 N
# 3                        NaN                                 N
#
#   eia solar Net Metering DC Capacity (MW)  \
# 0                                     NaN
# 1
# 2
# 3
#
#   eia solar Virtual Net Metering Agreement?  \
# 0                                       NaN
# 1                                         N
# 2                                         N
# 3                                         N
#
#   eia solar Virtual Net Metering DC Capacity (MW) eia solar Latitude  \
# 0                                             NaN                NaN
# 1                                                          30.421400
# 2                                                          28.883196
# 3                                                          29.271667
#
#   eia solar Longitude            eia solar plant_name_county
# 0                 NaN                                    NaN
# 1          -97.461400  East Blackland Solar Project 1 Travis
# 2          -99.178605                       Elara Solar Frio
# 3          -98.444722         OCI Alamo Solar I Hybrid Bexar
#
# [4 rows x 53 columns]

# %%
# panhandle
unit_list = [
    'MISAE SOLAR U1',

]

merged_df_panhandle = merge_cdr_with_eia_info(unit_list, cdr_df, eia_df)
merged_df_panhandle
# Out:
#   cdr file unit name cdr unit code  cdr file nameplate ac mw cdr file county  \
# 0     MISAE SOLAR U1   MISAE_UNIT1                     121.4       CHILDRESS
#
#   eia plant name eia county  eia nameplate ac    eia lat     eia lon  \
# 0    Misae Solar  Childress             240.0  34.380532 -100.099625
#
#    eia solar Utility ID  ... eia solar Thin-Film (CIGS)?  \
# 0                 63048  ...                         NaN
#
#    eia solar Thin-Film (Other)? eia solar Other Materials?  \
# 0                           NaN                        NaN
#
#   eia solar Net Metering Agreement? eia solar Net Metering DC Capacity (MW)  \
# 0                                 N
#
#   eia solar Virtual Net Metering Agreement?  \
# 0                                         N
#
#   eia solar Virtual Net Metering DC Capacity (MW) eia solar Latitude  \
# 0                                                          34.380532
#
#   eia solar Longitude eia solar plant_name_county
# 0         -100.099625       Misae Solar Childress
#
# [1 rows x 53 columns]

# %%
# coastal
unit_list = [
    'NEBULA SOLAR (RAYOS DEL SOL) U1',
'WAGYU SOLAR',
'WESTORIA SOLAR U1',

]
merged_df_coastal = merge_cdr_with_eia_info(unit_list, cdr_df, eia_df)
merged_df_coastal
# Out:
# No strong EIA match for 'WESTORIA SOLAR U1 BRAZORIA' (Best guess: Blue Wing Solar Energy Generation Bexar, Score: 86)
# ⚠ No EIA Solar row matching CDR: WESTORIA SOLAR U1 BRAZORIA
#                 cdr file unit name cdr unit code  cdr file nameplate ac mw  \
# 0  NEBULA SOLAR (RAYOS DEL SOL) U1  NEBULA_UNIT1                     137.5
# 1                      WAGYU SOLAR     WGU_UNIT1                     120.0
# 2                WESTORIA SOLAR U1     WES_UNIT1                     101.6
#
#   cdr file county eia plant name eia county  eia nameplate ac    eia lat  \
# 0         CAMERON   Nebula Solar    Cameron             135.0  26.090103
# 1        BRAZORIA          Wagyu   Brazoria             120.0  29.242304
# 2        BRAZORIA           None       None               NaN        NaN
#
#      eia lon  eia solar Utility ID  ... eia solar Thin-Film (CIGS)?  \
# 0 -97.798453               64917.0  ...                         NaN
# 1 -95.658144               62161.0  ...                         NaN
# 2        NaN                   NaN  ...                         NaN
#
#    eia solar Thin-Film (Other)? eia solar Other Materials?  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
#
#   eia solar Net Metering Agreement? eia solar Net Metering DC Capacity (MW)  \
# 0                                 Y                                   181.5
# 1                                 N
# 2                               NaN                                     NaN
#
#   eia solar Virtual Net Metering Agreement?  \
# 0                                         N
# 1                                         N
# 2                                       NaN
#
#   eia solar Virtual Net Metering DC Capacity (MW) eia solar Latitude  \
# 0                                                          26.090103
# 1                                                          29.242304
# 2                                             NaN                NaN
#
#   eia solar Longitude eia solar plant_name_county
# 0          -97.798453        Nebula Solar Cameron
# 1          -95.658144              Wagyu Brazoria
# 2                 NaN                         NaN
#
# [3 rows x 53 columns]

# %% [markdown]
# Here's a function for getting timeseries data for the plants from gridstatus.io.

# %%
def export_specs_and_timeseries(
    merged_df,
    start_datetime,
    end_datetime,
    api_key,
    output_spec_folder=".",
    output_timeseries_folder='.',
    cert_path=None,
    sleep_time=0
):
    dataset_name="ercot_sced_gen_resource_60_day"
    filter_column="resource_name"
    
    # drop rows where there was no EIA match
    merged_df = merged_df[merged_df['eia plant name'].notnull()]

    # GridStatus Client
    if cert_path is not None:
        os.environ["REQUESTS_CA_BUNDLE"] = cert_path
    client = GridStatusClient(api_key)
    date_fmt = f"{start_datetime[:10].replace('-', '')}-{end_datetime[:10].replace('-', '')}"


    for unit in merged_df['cdr file unit name']:
        print(f"\nProcessing: {unit}")
        unit_df = merged_df[merged_df['cdr file unit name'] == unit].copy()
        unit_code = unit_df['cdr unit code']

        # Save SPEC CSV
        spec_filename = f"{unit.replace(' ', '_')}_specs.csv"
        unit_df.to_csv(os.path.join(output_spec_folder, spec_filename), index=False)
        print(f"✅ Saved specs: {spec_filename}")


        # Get GridStatusIO time series
        try:
            ts_df = client.get_dataset(
                dataset=dataset_name,
                start=start_datetime,
                end=end_datetime,
                filter_column=filter_column,
                filter_value=unit_code,
            )
            ts_df["UNIT NAME"] = unit
            ts_df["UNIT CODE"] = unit_code


            ts_filename = f"{unit.replace(' ', '_')}_actual_power_{date_fmt}.csv"
            ts_df.to_csv(os.path.join(output_timeseries_folder, ts_filename), index=False)
            print(f"✅ Saved timeseries: {ts_filename}")
        except Exception as e:
            print(f"❌ GridStatus error for {unit}: {e}")
        if sleep_time > 0:
            print('sleeping for ' + str(sleep_time) + ' sec.')
            time.sleep(sleep_time)

# %% [markdown]
# Get data for all plants for 2024-03-10 to 2025-03-16:

# %%
merged_df = pd.concat([merged_df_coastal,merged_df_south,merged_df_north,merged_df_panhandle,merged_df_west],axis=0)
start_datetime="2024-03-10 12:00"
end_datetime="2025-03-16 12:00"

export_specs_and_timeseries(merged_df,start_datetime,end_datetime,api_key,
                            output_spec_folder="output_specs",
                            output_timeseries_folder='output_timeseries',
                            sleep_time=30) # <-- may need to adjust this to avoid API rate limits
# Out:
# Processing: NEBULA SOLAR (RAYOS DEL SOL) U1
# ✅ Saved specs: NEBULA_SOLAR_(RAYOS_DEL_SOL)_U1_specs.csv
# Fetching Page 1...Done in 25.64 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: NEBULA_SOLAR_(RAYOS_DEL_SOL)_U1_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: WAGYU SOLAR
# ✅ Saved specs: WAGYU_SOLAR_specs.csv
# Fetching Page 1...Done in 25.91 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: WAGYU_SOLAR_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: EAST BLACKLAND SOLAR (PFLUGERVILLE SOLAR)
# ✅ Saved specs: EAST_BLACKLAND_SOLAR_(PFLUGERVILLE_SOLAR)_specs.csv
# Fetching Page 1...Done in 25.12 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: EAST_BLACKLAND_SOLAR_(PFLUGERVILLE_SOLAR)_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: ELARA SOLAR
# ✅ Saved specs: ELARA_SOLAR_specs.csv
# Fetching Page 1...Done in 18.64 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: ELARA_SOLAR_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: OCI ALAMO 1 SOLAR
# ✅ Saved specs: OCI_ALAMO_1_SOLAR_specs.csv
# Fetching Page 1...Done in 25.35 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: OCI_ALAMO_1_SOLAR_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: CONIGLIO SOLAR
# ✅ Saved specs: CONIGLIO_SOLAR_specs.csv
# Fetching Page 1...Done in 52.6 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: CONIGLIO_SOLAR_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: IMPACT SOLAR
# ✅ Saved specs: IMPACT_SOLAR_specs.csv
# Fetching Page 1...Done in 24.52 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: IMPACT_SOLAR_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: KELLAM SOLAR
# ✅ Saved specs: KELLAM_SOLAR_specs.csv
# Fetching Page 1...Done in 25.25 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: KELLAM_SOLAR_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: LILY SOLAR
# ✅ Saved specs: LILY_SOLAR_specs.csv
# Fetching Page 1...Done in 24.55 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: LILY_SOLAR_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: NOBLE SOLAR U1
# ✅ Saved specs: NOBLE_SOLAR_U1_specs.csv
# Fetching Page 1...Done in 25.47 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: NOBLE_SOLAR_U1_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: MISAE SOLAR U1
# ✅ Saved specs: MISAE_SOLAR_U1_specs.csv
# Fetching Page 1...Done in 26.52 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: MISAE_SOLAR_U1_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: ANSON SOLAR U1
# ✅ Saved specs: ANSON_SOLAR_U1_specs.csv
# Fetching Page 1...Done in 24.5 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: ANSON_SOLAR_U1_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: ARAGORN SOLAR
# ✅ Saved specs: ARAGORN_SOLAR_specs.csv
# Fetching Page 1...Done in 20.45 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: ARAGORN_SOLAR_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: AZURE SKY SOLAR U1
# ✅ Saved specs: AZURE_SKY_SOLAR_U1_specs.csv
# Fetching Page 1...Done in 16.22 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: AZURE_SKY_SOLAR_U1_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: BLUEBELL SOLAR II 1 (CAPRICORN RIDGE 4)
# ✅ Saved specs: BLUEBELL_SOLAR_II_1_(CAPRICORN_RIDGE_4)_specs.csv
# Fetching Page 1...Done in 24.61 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: BLUEBELL_SOLAR_II_1_(CAPRICORN_RIDGE_4)_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: CASTLE GAP SOLAR
# ✅ Saved specs: CASTLE_GAP_SOLAR_specs.csv
# Fetching Page 1...Done in 15.67 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: CASTLE_GAP_SOLAR_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: GALLOWAY 1 SOLAR
# ✅ Saved specs: GALLOWAY_1_SOLAR_specs.csv
# Fetching Page 1...Done in 25.38 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: GALLOWAY_1_SOLAR_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: GREASEWOOD SOLAR 1
# ✅ Saved specs: GREASEWOOD_SOLAR_1_specs.csv
# Fetching Page 1...Done in 38.96 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: GREASEWOOD_SOLAR_1_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: HOLSTEIN SOLAR 1
# ✅ Saved specs: HOLSTEIN_SOLAR_1_specs.csv
# Fetching Page 1...Done in 26.46 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: HOLSTEIN_SOLAR_1_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
#
# Processing: LAPETUS SOLAR
# ✅ Saved specs: LAPETUS_SOLAR_specs.csv
# Fetching Page 1...Done in 25.64 seconds.
#
# Total number of rows: 35517
# ✅ Saved timeseries: LAPETUS_SOLAR_actual_power_20240310-20250316.csv
# sleeping for 30 sec.
